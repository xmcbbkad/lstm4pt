# %%
from matplotlib.backend_bases import MouseButton
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

x=np.arange(0,10,0.2)
y=np.sin(2 * np.pi * x)
fig4, ax4 = plt.subplots(figsize=(20,20))
ax4.plot(x, y)
ax4.set_xlim(0,)
ax4.set_ylim(-1,)
line_x = ax4.axhline(y=0,ls="dashdot",c="grey")#初始化水平直线
line_y = ax4.axvline(x=0,ls="dashdot",c="grey")#初始化垂直直线


def on_move(event):
    # get the x and y pixel coords
    x, y = event.x, event.y
    if event.inaxes:
        ax = event.inaxes  # the axes instance
        print('data coords %f %f' % (event.xdata, event.ydata))
        line_x.set_ydata(event.ydata)#添加水平直线
        line_y.set_xdata(event.xdata)#添加垂直直线
        fig.canvas.draw_idle() # 绘图动作实时反映在图像上


def on_click(event):
    if event.button is MouseButton.LEFT:
        print('disconnecting callback')
        plt.disconnect(binding_id)


binding_id = plt.connect('motion_notify_event', on_move)
plt.connect('button_press_event', on_click)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

plt.plot([1,2,3,4,5,6,7], [10, 50, 100, 23,15,28,45], linewidth = 3, c = 'g')
# Out:
# <img src="data:image/png;base64,..." width="300">
